# %%
import pandas as pd

marketing_db = pd.read_csv("C:/Users/marco/Downloads/marketing_AB.csv/marketing_AB.csv")

# Setting lowercase column names and remove leading and trailing characters:  
marketing_db.columns.str.lower()
marketing_db

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:MarcoBez72ApriliaRS-GP26@localhost/marketing_data")

marketing_db.to_sql(
    name="marketing_data",
    con=engine,
    if_exists="append",
    index=False
)
