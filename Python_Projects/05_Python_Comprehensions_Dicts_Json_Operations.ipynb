# %%
"""
We have a list of numbers:

numbers = [4, 10, 50, 100, 128, 71, 46]

Create a new list whose elements are the same as numbers, each increased by 10, using a list comprehension.
"""

numbers = [4, 10, 50, 100, 128, 71, 46]
plus_10_numbers = [n + 10 for n in numbers]

print(plus_10_numbers)

# %%
"""
We have a list of numbers:

numbers = [4, 10, 50, 100, 128, 71, 46]

Create a new list whose elements are the same as numbers but doubled, using a list comprehension.
"""

numbers = [4, 10, 50, 100, 128, 71, 46]
doubled_numbers = [n * 2 for n in numbers]

print(doubled_numbers)

# %%
"""
We have a list of names:

names = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]

Create a new list whose elements are the initials of the names, using a list comprehension.
"""

names = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
initials_names = [name[0] for name in names]

print(initials_names)

# %%
"""
We have a list of names:

names = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]

Create a new list whose elements are the initials of the names followed by a dot, using a list comprehension.
"""

names = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
initials_names = [name[0] + "." for name in names]

print(initials_names)

# %%
"""
We have a list of tax ids:

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D", "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

Create a list that contains (for each tax ids) only the characters related to the name, using a list comprehension.
"""

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D", "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

# Extract characters related to the name (first 6 characters of each tax code)
name_char = [n[0:6] for n in tax_ids]

print(name_char)

# %%
"""
We have a list of Italian tax codes (Codice Fiscale):

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D", "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

Create two lists:
- one containing (for each CF) only the characters related to the name
- one containing (for each CF) only the characters related to the surname

Both must be created using list comprehensions.
"""

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D", "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

# Extract characters corresponding to the "name" part (positions 3 to 5)
first_name_char = [n[3:6] for n in tax_ids]

# Extract characters corresponding to the "surname" part (positions 0 to 2)
last_name_char = [n[0:3] for n in tax_ids]

print(first_name_char, last_name_char)

# %%
"""
We have a list of tax codes:

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D",
             "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

Create a list that contains only the tax codes of people born in '95 using a list comprehension.
"""

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D",
            "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

born_in_95 = [n for n in tax_ids if n[6:8] == "95"]

print(born_in_95)

# %%
"""
We have a list of tax codes:

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D",
            "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

Create a list that contains the last five characters of the tax codes
of people born in '95, using a list comprehension.
"""

tax_ids = ["ABCDEF95G01A123B", "GHIJKL91M02A321C", "MNOPQR89S03A456D",
            "STUVWX95Z04A654E", "XYZABC01D05A789F", "DEFGHI95J06A987G"]

born_in_95 = [n[-5:] for n in tax_ids if n[6:8] == "95"]

print(born_in_95)

# %%
"""
We have a list of students:

students = ["Alex", "Bob", "Cindy", "Dan", "Emma",
             "Faith", "Grace", "Henry", "Isabelle", "John"]

We want to divide the students into two teams for a Uno tournament as follows:
the first half goes to one team, and the second half goes to the other team.

Create two lists for each team and display them at the end.
"""

students = ["Alex", "Bob", "Cindy", "Dan", "Emma",
            "Faith", "Grace", "Henry", "Isabelle", "John"]

squad_1 = [s for s in students[:len(students)//2]]
squad_2 = [s for s in students[len(students)//2:]]

print(squad_1, squad_2)

# %%
"""
We have a list of price strings in dollars that were mistakenly written
with the euro symbol instead:

prices = ["100 €", "200 €", "500 €", "10 €", "50 €", "70 €"]

Replace the euro symbol (€) with the dollar symbol ($) for each string
in the list using a list comprehension.
"""

prices = ["100 €", "200 €", "500 €", "10 €", "50 €", "70 €"]

dollar_prices = [p.replace("€", "$") for p in prices]

print(dollar_prices)

# %%
"""
We have a list of students:

students = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry", "Isabelle", "John"]

We want to divide the students into two teams for a Uno tournament as follows:
we select names in even positions for one team, and names in odd positions for the other team.

We create two lists for each team, and finally display them.
"""

students = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry", "Isabelle", "John"]

# Split using slicing (clean and efficient way)

team_1 = students[::2]   # even positions (0, 2, 4, ...)
team_2 = students[1::2]  # odd positions (1, 3, 5, ...)

print(team_1, team_2)

# %%
"""
We have a list of earnings over the last 12 months (from January to December):

earnings = [100, 90, 70, 40, 50, 80, 90, 120, 80, 20, 50, 50]

We need to compare, printing everything, each month's earnings with the average of previous months.

Example output:
Month 1: 100 €
Month 2: 90 € (previous avg: 100 €)
Month 3: 70 € (previous avg: 95 €)
"""

earnings = [100, 90, 70, 40, 50, 80, 90, 120, 80, 20, 50, 50]

# First month has no previous average
print("Month 1:", str(earnings[0]) + " €")

# From second month onward, compute previous average
print(
    "".join([
        "Month " + str(pos + 1) + ": " +
        str(earnings[pos]) + " € (previous avg: " +
        str(sum(earnings[:pos]) // pos) + " €)\n"
        for pos in range(1, len(earnings))
    ])
)

# %%
"""
We have a list with the earnings of the last 12 months (from January to December):

earnings = [100, 90, 70, 40, 50, 80, 90, 120, 80, 20, 50, 50]

We need to compare, printing everything to the screen, each month's earnings with the average of the previous months,
and specify in the output whether it is higher or lower than the average.
"""

earnings = [100, 90, 70, 40, 50, 80, 90, 120, 80, 20, 50, 50]

print("Month 1:", str(earnings[0]))

print("".join([
    "Month " + str(pos + 1) + ": " + str(earnings[pos]) +
    ", previous average: " + str(sum(earnings[:pos]) // pos) +
    " - we are above the average\n"
    if (sum(earnings[:pos]) // pos) > earnings[pos]
    else
    "Month " + str(pos + 1) + ": " + str(earnings[pos]) +
    ", previous average: " + str(sum(earnings[:pos]) // pos) +
    " - we are below the average\n"
    for pos in range(1, len(earnings))
]))

# %%
"""
Part 1:

Visit http://www.datiopen.it/it/opendata/Mappa_dei_pub_circoli_locali_in_Italia to download the dataset of pubs, clubs, and venues in Italy.

Note: to read it using the open() function, we must add the parameter encoding="latin1", for example:

f = open(file_path, "r", encoding="latin1")

Part 2:

Explore the dataset:

1. How many records are there in total?
2. What are the metadata fields?
3. Print the first element
4. Print the last element
5. Can we print a random element?
6. What insertion years are present?
7. How many activities are in the bounding box longitude 9–10 and latitude 45–46?
8. How many activities are in the province of Vicenza?
9. How many wine bars (enoteche) are there, and what are their names?
10. How many activities are in Lazio and Abruzzo together?
"""

# Opening the file + solving using open().readline(s)()

import json

file = open(
    "[local-file-path]",
    "r",
    encoding="latin1"
)

data = json.load(file)

# 1. How many records are there in total?
print(len(data))

# 2. What are the metadata fields?
print(data[0].keys())

# 3. Print the first element
print(data[0])

# 4. Print the last element
print(data[-1])

# 5. Can we print a random element?
import random

pos = random.randint(0, len(data) - 1)
print(data[pos])

# 6. What insertion years are present?
insertion_years = set()

for x in data:
    insertion_years.add(x["canno_inserimento"])

print(insertion_years)

# Alternative with comprehension
insertion_years = set(x["canno_inserimento"] for x in data)
print(insertion_years)

# 7. How many activities are in longitude 9–10 and latitude 45–46?
businesses = []

for x in data:
    if 9 < float(x["clongitudine"]) < 10 and 45 < float(x["clatitudine"]) < 46:
        businesses.append(x["cnome"])

print(len(businesses))

# Alternative with comprehension
businesses = [
    x["cnome"]
    for x in data
    if 9 <= float(x["clongitudine"]) <= 10 and 45 <= float(x["clatitudine"]) <= 46
]

print(len(businesses))

# 8. How many activities are in the province of Vicenza?
vicenza_businesses = []

for x in data:
    if x["cprovincia"].lower() == "vicenza":
        vicenza_businesses.append(x["cnome"])

print(len(vicenza_businesses))

# Alternative with comprehension
vicenza_businesses = [
    x["cnome"] for x in data if x["cprovincia"].lower() == "vicenza"
]

print(len(vicenza_businesses))

# 9. How many wine bars are there, and what are their names?
enoteche = []

for x in data:
    if "enoteca" in x["cnome"].lower():
        enoteche.append(x["cnome"])

print("In total there are", len(enoteche), "wine bars. Their names are:\n", enoteche)

# Alternative with comprehension
enoteche = [x["cnome"] for x in data if "enoteca" in x["cnome"].lower()]

print("In total there are", len(enoteche), "wine bars. Their names are:\n", enoteche)

# 10. How many activities are in Lazio and Abruzzo together?
lazio_abruzzo_businesses = []

for x in data:
    if x["cregione"].lower() == "lazio" or x["cregione"].lower() == "abruzzo":
        lazio_abruzzo_businesses.append(x["cnome"])

print(
    "\nOverall, between Lazio and Abruzzo there are",
    len(lazio_abruzzo_businesses),
    "activities.\n\nTheir names are:\n\n",
    lazio_abruzzo_businesses,
    "\n"
)

# Alternative with comprehension
lazio_abruzzo_businesses = [
    x["cnome"]
    for x in data
    if x["cregione"].lower() == "lazio" or x["cregione"].lower() == "abruzzo"
]

print(
    "\nOverall, between Lazio and Abruzzo there are",
    len(lazio_abruzzo_businesses),
    "activities.\n\nTheir names are:\n\n",
    lazio_abruzzo_businesses,
    "\n"
)


# Opening the file + solving using Pandas

import pandas as pd

df = pd.read_csv("pub.csv", sep=";")

print("The file contains " + str(len(df)) + " rows.")

# What are the metadata fields?
print("\nThe metadata fields are:")
for col in df.columns.values:
    print("- " + col)

# Print the first element
print(df[:1])

# Print the last element
print(df[-1:])

# Can we print a random element?
from random import randint

x = randint(0, len(df) - 1)
print(df[x:x+1])

# What insertion years are present?
years = []

for x in df["Anno inserimento"]:
    if x not in years:
        years.append(x)

years.sort()
print(years)

# How many activities are in longitude 9–10 and latitude 45–46?
long_mask = df["Longitudine"].between(9, 10)
lat_mask = df["Latitudine"].between(45, 46)

print(df[long_mask & lat_mask])

# How many activities are in the province of Vicenza?
vicenza_mask = df["Provincia"] == "VICENZA"

print("In the province of Vicenza there are " + str(len(df[vicenza_mask])) + " activities.")

# How many wine bars are there, and what are their names?
enoteche = []

for name in df["Nome"]:
    if "ENOTECA" in str(name).upper():
        enoteche.append(name)

print("Wine bars found:\n")
print("\n".join(enoteche), "\n")
print("Total: " + str(len(enoteche)) + " wine bars.")

# Alternative
count = 0

print("Wine bars found:\n")
for el in df["Nome"]:
    if "ENOTECA" in str(el).upper():
        print(el)
        count += 1

print("\nTotal: " + str(count) + " wine bars.")

# How many activities are in Lazio and Abruzzo together?
lazio_mask = df["Regione"] == "Lazio"
abruzzo_mask = df["Regione"] == "Abruzzo"

print(
    "In Lazio and Abruzzo there are "
    + str(len(df[lazio_mask | abruzzo_mask]))
    + " activities."
)
