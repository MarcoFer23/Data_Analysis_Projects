# %%
import chime

# Let's print available Chime themes
print(chime.themes())

# %%
# Let's select a theme to play sounds (for instance, 'zelda', or 'sonic')
chime.theme('zelda')

# %%
chime.success()

# %%
chime.warning()

# %%
chime.info()

# %%
chime.error()
