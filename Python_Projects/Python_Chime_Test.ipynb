# %%
import chime

print(chime.themes())
# Out:
# ['big-sur', 'chime', 'mario', 'material', 'pokemon', 'sonic', 'zelda']

# %%
chime.theme('zelda')

# %%
chime.success()

# %%
chime.warning()

# %%
chime.info()

# %%
chime.error()
